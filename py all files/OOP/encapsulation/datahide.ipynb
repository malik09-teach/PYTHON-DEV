# %%
    # encapsulation in python is for concept to unbderstand how the data can be organizied  other wise it be access
    # the access modifer can also be access with out the building pilic funs 
    # the encapsultaiion is the unit prvent the user from the direct acess of the data
# access modifier 
#1.private 
#2.protected
#3.public

# %%
    # private
    # __ by using double under score can be the achive the private member and function 
class A:
    def __init__(self):
        self.__name="malik"
        self.__age=32

    def __funhide(self):
          print(f"name:{self.__name} \nage:{self.__age}")
     
    def funcall(self):
        self.__funhide()



## calling through object 
obj=A()
print ("call the publically fun to call the private member and the fun")
obj.funcall()
## here the private fun and cant be accesbble 
#obj.__funhide()
 #if we accessing the private method and the varaible from the object it will not accessable

# if we want to access the  private member out call in python

print ("dirctly access by on the object:",obj._A__name)
print(" the pivate member call by using the obejct")
obj._A__funhide()
#dir(obj)
# Out:
# call the publically fun to call the private member and the fun
# name:malik
# age:32
# dirctly access by on the object: malik
#  the pivate member call by using the obejct
# name:malik
# age:32

# %%
    # protected
    # _ by using double under score can be the achive the private member and function 
    # this is use for the inheriting the class for that can be only use
    # can also acces out of the class as publicaly
class A:
    def __init__(self,name,age):
        self._name=name
        self._age=age

    def _funhide(self):
          print(f"name:{self._name} \nage:{self._age}")
     
    def funcall(self):
        self._funhide()


class B(A):
    def __init__(self,name, age):
          super().__init__(name,age)

    def b_name(self):
        print (self._name)
        print(self._age)    
## calling through object 
obj=A("mk",45)
print ("call the publically fun to call the private member and the fun")
obj.funcall()

#protected fun can be also accessible
#obj._funhide() 
## proteceted can be accessbale out of the class 
#obj._age
 #if we accessing the private method and the varaible from the object it will not accessable

# if we want to access the  private member out call in python

#print ("dirctly access by on the object:",obj._A_name)
#print(" the pivate member call by using the obejct")
#obj._A_funhide()
#dir(obj)
print ("calling from b class")
obj2=B("khan",33)
obj2.b_name()
# Out:
# call the publically fun to call the private member and the fun
# name:mk
# age:45
# calling from b class
# khan
# 33
