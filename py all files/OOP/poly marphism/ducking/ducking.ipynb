# %%
## ducking is the dynamic type of the objectec which may be change but the functionlity must be same

# %%
## 
class duck:

    def execute(self,ide):
       ide.extcuteable()


class pycharmn:
    
   def extcuteable(self):
    print("pycharm is running ...")
    print("pycharm is running ...")
    print("pycharm is running ...")
    print("pycharm is running ...")

class editer:
    
   def extcuteable(self):
    print("editer  is running ...")

# %%
ide=editer()

lap1=duck()

lap1.execute(ide)
# Out:
# editer  is running ...
