# %%
import pandas as pd

# %%
## series

# %%
data = [10, 20, 30, 40]
s = pd.Series(data)

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# data frame 

data={"name : abbas ","name : awais","name : murtaza","age :10 ","age :23 ","age :20 "
}

df=pd.DataFrame(data)
df
# Out:
#                 0
# 0        age :10
# 1    name : awais
# 2        age :20
# 3   name : abbas
# 4  name : murtaza
# 5        age :23

# %%
import pandas as pd

data = [
    {"Name": "shoiab", "Age": 25, "Role": "Dev"},
    {"Name": "arslan", "Age": 30, "Role": "Designer"},
    {"Name": "abbas ", "Age": 35, "Role": "Manager"}
]

df2 = pd.DataFrame(data)

df2
# Out:
#      Name  Age      Role
# 0  shoiab   25       Dev
# 1  arslan   30  Designer
# 2  abbas    35   Manager
