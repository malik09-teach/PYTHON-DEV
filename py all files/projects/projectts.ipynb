# %%
class home:
    def __init__(self,room_no,per_R_L,per_fan,use_t):
        self.room_no=room_no
        self.per_R_L=per_R_L
        self.per_fan=per_fan
        self.use_t=use_t 

    def __power_use (slef):
            return (self.per_R_L*self.use_t)+(self.per_fan*self.use_t)


    def _totcost (self):
        return (self.__power_use()*15.4 )*self.room_no 


if __name__ == "__main__":
    def main():
        homeno= int(input("Enter the number of homes: "))

        for i in range(homeno):
            room_no=int(input("Enter the number of rooms in your home: "))
            fans=int(input("Enter the number of rooms in your home: "))
            lights=int(input("Enter the number of rooms in your home: "))
            hours=int(input("Enter the number of rooms in your home: "))

            home1[i]=home(room_no,lights,fans,hours)
            print("Total cost of power consumption in your home is:",home1[i]._totcost())
            print("************************************")
