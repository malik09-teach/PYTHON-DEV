# %%
# importing the package speecific function ,class 
# santyax form "package" import "function /class"
from math import sqrt

def sqr_num(num):
    return sqrt(num)

num=int (input("enter number :"))
print("square root of ",num,":",sqr_num(num))
# Out:
# square root of  16 : 4.0

# %%
# to import specific  the funtions/classes

from math import sqrt,pi 

print(math.sqrt(15))
print (math.pi)
# Out:
# 3.872983346207417
# 3.141592653589793

# %%
# to import entire  build in package 
from math import *
print(math.sin(90))
print(math.cos(90))
# Out:
# 0.8939966636005579
# -0.4480736161291701

# %%
## to laod the external library such as the numpy will get downlaod pip intall -r \

import numpy as np

np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
# how to import the custome build package and its function
#from artpacks.ARTHIMETIC import *
from artpacks.ARTHIMETIC import add,min

add(5,22)
min(3,4)
# Out:
# 1

# %%
## importing the sub packs 
#from artpacks.subpack.evenfun import * to import all the funs 
from artpacks.subpack.evenfun import even

even(5)
# Out:
# 'odd'

# %%
def math_add(x1,x2):
    return x1+x2
