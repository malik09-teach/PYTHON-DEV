# %%
#if in python 
## use for the condition weather it is right or not 

## let doing some example 

number =10 

if number >5:
    print ("number is greater than 5 ")



#if 
# elif
# Out:
# number is greater than 5

# %%
## let add else state ment also which determine that the  number is less then number 
# which give in the condition 


if number>15:
    print ("number is greater than 15 ")
else :
    print ("number is less than 15 ")
# Out:
# number is less than 15

# %%
# elif statments 

number1=15
if number1 > 15:
    print ("number not equal 15 ")
if num==0:
    print("num is zero")    
elif number1 == 15:
    print ("number is equal to 15 ")

else:
    print ("number is less than 15 ")
# Out:
# number is equal to 15

# %%
#nested checking

num=int (input("enter number :"))

if (num>0):
    if(num%2==0):
        print("number is positive and even")
    else:
        print("number is positive and odd")

else:
    if(num==0):
        print("number is zero ")
    else:
        print("number is negative")
# Out:
# number is positive and even

# %%
#calculator
num1 = int(input("enter first number :"))
num2 = int(input("enter second number :"))
operation = input("enter operation (+, -, *, /): ")

result = None # Initialize result

if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error: Division by zero is not allowed."
else:
    result = "Error: Invalid operation."

# Only one print statement at the end
print(result)
# Out:
# 10.0
