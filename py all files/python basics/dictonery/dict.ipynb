# %%
## the  dictonery data struct
## store values in the  pair forms
#  key and value 
## like mongo db 
'''
1:Introduction to Dictionaries
2:Creating Dictionaries
3:Accessing Dictionary Elements
4:Modifying Dictionary Elements
5:Dictionary Methods
6:Iterating Over Dictionaries
7:Nested Dictionaries
8:Dictionary Comprehensions
9:Practical Examples and Common Errors

'''
# Out:
# '\n1:Introduction to Dictionaries\n2:Creating Dictionaries\n3:Accessing Dictionary Elements\n4:Modifying Dictionary Elements\n5:Dictionary Methods\n6:Iterating Over Dictionaries\n7:Nested Dictionaries\n8:Dictionary Comprehensions\n9:Practical Examples and Common Errors\n\n'

# %%
##  creating 

dictonery={}
print (dictonery,type(dictonery))

# fun
d1=dict()
print (d1,type(d1))
# Out:
# {} <class 'dict'>
# {} <class 'dict'>

# %%
## elements ASSIGNMENT in dict

d2={"name":"malik", "age":23 ,"edu":"BSCS"}
print (" overal by on var:")

#accessing the elements
print (d2)  

## the elements by on the index key and the value
print ("by on index:")

print(d2['name'])
print(d2['age'])
print(d2['edu'])

# by on  getfun  
print ("by on get fun:")

print (d2.get('name'))
print (d2.get('age'))
print (d2.get('edu'))
# Out:
#  overal by on var:
# {'name': 'malik', 'age': 23, 'edu': 'BSCS'}
# by on index:
# malik
# 23
# BSCS
# by on get fun:
# malik
# 23
# BSCS

# %%
    ## modification 
## the  dict key  cannot be modify butt the only can we do is  the value can be change

print ("befor the updated dict:")
print (d2)

print( "after the  update")
d2['name']= "malik abbas"
print(d2)

# add of some varaible 

d2['email:']= "  malikabbaskhan@gamil.com"

print(d2)
# Out:
# befor the updated dict:
# {'name': 'malik abbas', 'age': 23, 'edu': 'BSCS', 'email:': '  malikabbaskhan@gamil.com'}
# after the  update
# {'name': 'malik abbas', 'age': 23, 'edu': 'BSCS', 'email:': '  malikabbaskhan@gamil.com'}
# {'name': 'malik abbas', 'age': 23, 'edu': 'BSCS', 'email:': '  malikabbaskhan@gamil.com'}

# %%
## the function by in which can get key values and the both pairs 

print(d2.keys())

print(d2.values())

print(d2.items())
# Out:
# dict_keys(['name', 'age', 'edu'])
# dict_values(['malik abbas', 23, 'BSCS'])
# dict_items([('name', 'malik abbas'), ('age', 23), ('edu', 'BSCS')])

# %%
#shllow  copies 

        #01  copy with same update:               
d3={ 'dept':"cs",'section':"sect d" ,'id':"200233229"}

## let copy 
d4 =d3


print ("orignal:",d3)
print ("copy :",d4)




print ("before update ")

print (d3)
print (d4)


print ("after update ")

d3['dept']="BSDS"

print ()
print (d3)
print (d4)
# Out:
# orignal: {'dept': 'cs', 'section': 'sect d', 'id': '200233229'}
# copy : {'dept': 'cs', 'section': 'sect d', 'id': '200233229'}
# before update
# {'dept': 'cs', 'section': 'sect d', 'id': '200233229'}
# {'dept': 'cs', 'section': 'sect d', 'id': '200233229'}
# after update
#
# {'dept': 'BSDS', 'section': 'sect d', 'id': '200233229'}
# {'dept': 'BSDS', 'section': 'sect d', 'id': '200233229'}

# %%
    ## let use the funtion  which not update the previous list 
# using the copy funciton 
d6=d3.copy()
#let print 
print ("copy:",d6)
print ("orignal:",d3)

#  now update the value 
d3['section']="sect F"
## print both 

print ("copy after update:",d6)
print ("the orignal after  update:",d3)
# Out:
# copy: {'dept': 'cs', 'section': 'sect F', 'id': '200233229'}
# orignal: {'dept': 'cs', 'section': 'sect F', 'id': '200233229'}
# copy after update: {'dept': 'cs', 'section': 'sect F', 'id': '200233229'}
# the orignal after  update: {'dept': 'cs', 'section': 'sect F', 'id': '200233229'}

# %%
## ittrating  by on the loop
 ## using dor loop on  items and on the  keys , values,items 

#let

i=0
for  keyes in d6.keys() :
    i=i+1
    print("key",i, ":",keyes)
# Out:
# key 1 : dept
# key 2 : section
# key 3 : id

# %%
## values 
i=0
for  val in d6.values() :
    i=i+1
    print("value",i, ":",val)

# %%
## by on item
i=0
for  ite in d6.items() :
    i=i+1
    print(i, "#","item:",ite)
# Out:
# 1 # item: ('dept', 'cs')
# 2 # item: ('section', 'sect F')
# 3 # item: ('id', '200233229')

# %%
## nasting

students={
'st1':{"name":"malik", "age":23 ,"edu":"BSCS"},
'st2':{"name":"khan", "age":21 ,"edu":"BSCS"}
}


print(students['st1'])
print("name:",students['st1']["name"])
# Out:
# {'name': 'malik', 'age': 23, 'edu': 'BSCS'}
# name: malik

# %%
## ittratting 

for stuinfo,vals in students.items():
    print(stuinfo,":",vals)
    for keys,vales in vals.items():
        print(keys,":",vales)

'''
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}") '''
# Out:
# st1 : {'name': 'malik', 'age': 23, 'edu': 'BSCS'}
# name : malik
# age : 23
# edu : BSCS
# st2 : {'name': 'khan', 'age': 21, 'edu': 'BSCS'}
# name : khan
# age : 21
# edu : BSCS
# '\nfor student_id,student_info in students.items():\n    print(f"{student_id}:{student_info}")\n    for key,value in student_info.items():\n        print(f"{key}:{value}") '

# %%
## compreansions 
 

d9={x:x**3  for x in range(1,11)}

print (d9)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}
