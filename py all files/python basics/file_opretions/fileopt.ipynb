# %%
#file opreation is the opreation in which can we read 
# access the file and create the file 
#modes
#r,w,w+,a
# read ,write ,write +,apennd

# %%
# let write+ in this mode if the file had not created it will create and will right 
# also the previous writing will the finesh
# w mode will only wirte the code not create the files 
filepath='exxamp.txt'
with open(filepath,mode='w+') as file :
    file.write("hello mr abbas\n")
    file.write ("what are you doing\n ")

## now to read the file 
with open (filepath,mode='r',newline='') as file :
    for row in file:
        print (row)
# Out:
# hello mr abbas
#
# what are you doing

# %%
   # let suppose i write the more lines int the 
with open(filepath,mode='w+') as file :
    file.write("where you belong from\n")
    file.write ("what are you doing\n ")

with open(filepath,mode='r')as file:
      for row in file:
         print(row)
         # if we see here all the all  previous line is fineshed 
         # if we want to wirte in the file after creaion so will 
         # wite in the append mode a
# Out:
# where you belong from
#
# what are you doing

# %%
## append mode will not remove the previous lines

with open(filepath, mode='a') as file:
    file.write("\n i belong from dir \n")
    file.write(" i am doing coding of pyhton")

with open(filepath, mode='r') as file:
        #  for i in file :
        #    print (i)
        
       print(file.read())
# Out:
# the temprature is normal
# we are living in the small village
#
#  i belong from dir
#  i am doing coding of pyhton

# %%
##  seek() function using the file to 

with open(filepath,mode='w+') as file :
    file.write("the temprature is normal\n")
    file.write ("we are living in the small village \n ")
 # move the cursor to the next line in the file  with respected n number of line
    file.seek(0)

#with open(filepath, mode='r') as file:
    print(file.read())
# Out:
# the temprature is normal
# we are living in the small village
