# %%
'''
Introduction to Functions
Defining Functions
Calling Functions
Function Parameters
Default Parameters
Variable-Length Arguments
Return Statement

'''

# %%
## a block of code which perform the specific funtion
# find the even num so i will write in the fun 
## syntax 
# def is basic word for define the fun

num=22
def even_odd():
    if num%2==0:
        print ("num is even: ",num)
    
    else:
        print ("num is odd:",num)

# %%
# calling the function 
# let call 01 
even_odd()
# Out:
# num is even:  22

# %%
# parameterize funs
# passing the values

# made a prime num fun

def isnumprime(num):
    if num <= 1:
        print("not a prime number:", num)
        return
    for i in range(2, num):
        if num % i == 0:
            print("not a prime number:", num)
            return
    print("prime number:", num)

# %%
isnumprime(9)
# Out:
# not a prime number: 9

# %%
## return values functions 
## multi args funs
def add(a,b):
    return a+b

# %%
## calling 

print ("sum:",add(2,3))     

sum_var=add(55,66)

print (sum_var)
# Out:
# sum: 5
# 121

# %%
## multi return statements :

def multi_args(strr,no):
    if no <50:
        return "not pass ",0
    else :     
       return strr,no

# %%
print ("the name at place ",multi_args("malik",33) )
# Out:
# the name at place  ('not pass ', 0)

# %%
# default parameter  in the  python 

#lett a welcome message in the browser 

def greet(name="guest"):
    print("Hello Mr:", name, "to the xyz site")

# %%
    # let call the function with out arg

greet()

## let with the arg 

greet ("abbas")
# Out:
# Hello Mr: guest to the xyz site
# Hello Mr: abbas to the xyz site

# %%
    ## the positonal args 


def varlenn(*args):
      for i in args:
        print ("pos : ",i, type(i))

# %%
    varlenn("malik abbas","khan",1001,1002 )
# Out:
# pos :  malik abbas <class 'str'>
# pos :  khan <class 'str'>
# pos :  1001 <class 'int'>
# pos :  1002 <class 'int'>

# %%
## pair val in fun 
## d/f and intialize

j=0
def var_p_pair(*var1,**var2):
      for i in var1:
        print ("pos:",i) 

      for key,val in var2.items():
         print (f" {key},{val}")

# %%
var_p_pair(1,2,3,4,"Krish",name="Krish",age="32",country="India")
# Out:
# pos: 1
# pos: 2
# pos: 3
# pos: 4
# pos: Krish
#  name,Krish
#  age,32
#  country,India
