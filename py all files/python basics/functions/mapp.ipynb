# %%
 # map funtion 
# the funtion such using the para meter and the other funtion to do task as their demand are map function and
#  the result by the address  in  the location 
#Make an iterator that computes the function using arguments from each of the iterables
#  Stops when the shortest iterable is exhausted.
# map(fun ,args)

# %%
    # a map fun in the python 
def square(x):
    return x*x

numbers=[1,2,3,4,5,6]
# if i go to find the square of all the number in the list will ittrarte 


#map(square ,numbers)# store at <map at 0x1f26136de70>

# let convert to the list so will show in the list 

list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
## using of lambda funciton in the in the map function 

list (map(lambda x:x%2==0,numbers))
# Out:
# [False, True, False, True, False, True]

# %%
# let convertion of data type

charc=['1','2','3','4']

# the dig int the char form in converted to the int type its now opreatable 

list(map(int,charc))
# Out:
# [1, 2, 3, 4]

# %%
## lwr to upr case 
latter=["malik ","abbas","khan"]

list (map(str.upper,latter))
# Out:
# ['MALIK ', 'ABBAS', 'KHAN']

# %%
def get_name(person):
    return person['name']

people=[
    {'name':'Krish','age':32},
    {'name':'Jack','age':33}
]
list(map(get_name,people))
# Out:
# ['Krish', 'Jack']

# %%
# multi irrt 
a1=[2,3,4]
a2=[3,5,6]

list (map(lambda x,y:x*y,a1,a2))

#limation 
#not be the irrtatable through over list upto the sec mat
# Out:
# [6, 15, 24]
