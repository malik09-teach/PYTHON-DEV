# %%
# lamda functions 
'''
anonymus functions which can do the specific task 
in one expression  
'''

# %%
# syantax 
lambda args:exp


variable=lambda args:exp



print ("the lambda is :::",lambda args:exp)
print ("type of variable :",type(variable))
# Out:
# the lambda is ::: <function <lambda> at 0x00000138D71B2160>
# type of variable : <class 'function'>

# %%
## addtion of two num 
## the args is the var and the exp is the logic that you want

# expression 
add=lambda a,b:a+b

## calling 
## if you want to call the lambda fun so you will 
# asign it in to variable 

print ("sum:",add(44,66))
# Out:
# sum: 110

# %%
## let even num
even= lambda x:x%2==0

even(5)
# Out:
# False

# %%
 ## multi args 

multi=lambda a,b,c:print(a,b,c)

multi("malik","39","a+")
# Out:
# malik 39 a+

# %%
#using  map funtion to take the list and the number  in the list
# actully take the both paramter 
num=[1,2,3,4,5,6,6]

list (map(lambda x:x**2,num))
# Out:
# [1, 4, 9, 16, 25, 36, 36]
