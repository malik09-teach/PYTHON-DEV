# %%
def main (x):
    try :
        if 10/x==0:
            return "divided"
    except Exception as e:
        print (e)



main(0)
# Out:
# division by zero

# %%
w=p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 w=p
#
# NameError: name 'p' is not defined

# %%
try:
 l=c
except :
     print("variables c isn't define  ")
# Out:
# variables c isn't define

# %%
try:
 l=c
except Exception as e :
     print(e)        
## exception was given by the compiler
# Out:
# name 'c' is not defined

# %%
## more except blocks and the nested
try:
    #10/num if i write the statement here  and if the the error find here so the 
    # futher checking will stop the compiler  
    # nested block in of try and catch 
    try:
        k = r # This line would not be reached if 10/0 is uncommented
    except:
        print ("the name the variable isnt define") 

    num= int(input("enter num"))
    div=10/num



except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Value error occurred!") 
except NameError:
    print("Variable 'r' is not assigned.")
except Exception as ex:
    print ("the main error",ex)    
else :
    print("else block",div)

finally:
    print ("final block:program execute successfuly")
# Out:
# the name the variable isnt define
# else block 1.4285714285714286
# final block:program execute successfuly

# %%
try:
    try:
        10/0
    except:
        print("zero error")
    file=open('file.txt','r')
    content=file.read()   

except FileNotFoundError as fnfe:
    print (fnfe)
except IOError as io:
    print(io)
else:
    print(content)    
finally:
    file.close()
    print("file closed")
# Out:
# zero error
# Hello, world!
#
# file closed
